# %%
# !pip3 install --upgrade pip
# Out:
# ...
#   Using cached pip-22.3.1-py3-none-any.whl (2.1 MB)
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 21.2.4
#     Uninstalling pip-21.2.4:
#       Successfully uninstalled pip-21.2.4
# ...

# %%
# !pip3 install snscrape

# %%
# !pip3 install git+https://github.com/JustAnotherArchivist/snscrape.git
# Out:
# ...
#   Cloning https://github.com/JustAnotherArchivist/snscrape.git to /private/var/folders/yc/z8rbch4d3ksft4qqr1m376r40000gn/T/pip-req-build-lmqatgs_
#   Running command git clone --filter=blob:none --quiet https://github.com/JustAnotherArchivist/snscrape.git /private/var/folders/yc/z8rbch4d3ksft4qqr1m376r40000gn/T/pip-req-build-lmqatgs_
#   Resolved https://github.com/JustAnotherArchivist/snscrape.git to commit 46a603053cfbc0ce3c54d43d7e1ac2427fa82b4d
#   Preparing metadata (setup.py) ... done
# ...

# %%
import os
import warnings 
import pandas as pd
import numpy as np
from datetime import date

# %%
today = date.today()
end_date = today
max_results = 100

bernie = '@SenSanders'
trump = '@realDonaldTrump'
clinton = '@HillaryClinton'
bush = '@JebBush'
rubio = '@marcorubio'


#trump = ['trump', 'Donald Trump'
 #        'hillary','AOC','Ted Cruz', ]
#['Hershel Walker ']'''

search_term = "AOC"
from_date = '2022-01-01'
#query = "snscrape --format '{content!r}'" + f" --max-results {max_results} --since {from_date} twitter-search '{search_term} until:{end_date}' > queried-tweets.json"


query = "snscrape --jsonl" + f" --max-results {max_results} --since {from_date} twitter-search '{search_term} until:{end_date}' > queried-tweets.json"
os.system(query)


if os.stat("queried-tweets.json").st_size == 0:
    print('get fucked lmao')
else:
    df_queried = pd.read_json("queried-tweets.json", lines = True)

# %%
#print(df_queried["content"][34])
#tract = df_queried[df_queried["likeCount"] > 2000]
#tract.head()
df_queried.head()
# Out:
#                             _type  \
# 0  snscrape.modules.twitter.Tweet
# 1  snscrape.modules.twitter.Tweet
# 2  snscrape.modules.twitter.Tweet
# 3  snscrape.modules.twitter.Tweet
# 4  snscrape.modules.twitter.Tweet
#
#                                                  url  \
# 0  https://twitter.com/WlLb4rt/status/15897696471...
# 1  https://twitter.com/TaintedSaint2/status/15897...
# 2  https://twitter.com/TwterNThMnky/status/158976...
# 3  https://twitter.com/JeffSyrop/status/158976955...
# 4  https://twitter.com/JeffJun80346519/status/158...
#
#                        date  \
# 0 2022-11-07 23:59:55+00:00
# 1 2022-11-07 23:59:40+00:00
# 2 2022-11-07 23:59:33+00:00
# 3 2022-11-07 23:59:32+00:00
# 4 2022-11-07 23:59:32+00:00
#
#                                           rawContent  \
# 0  @OhNoItsCorso @Zeviax3 @DashDobrofsky If someo...
# 1  @WildGorillaMan @jeffnesbit @AOC @elonmusk Hon...
# 2  @ReverendWarnock @AOC Final pitch vote against...
# ...
